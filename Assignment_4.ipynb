# %% [markdown]
# # Assignment_4

# %%
import pandas as pd

# %%
# Question 1

# %%
d={"Name":["Gaganjot Singh", "Sachin Luthra"],
   "Age":[20,21],
   "Number":[9988776655,7418529639]
  }
data=pd.DataFrame(d)
print(data)
# Out:
#              Name  Age      Number
# 0  Gaganjot Singh   20  9988776655
# 1   Sachin Luthra   21  7418529639

# %%
# Question 2

# %%
data=pd.read_csv("weather.csv")
print("First 5 rows: \n",data.head())
print("First 10 rows: \n",data.head(10))
'''
    If you want sum,mean,std of rows you can put data.sum(),data.mean(),
    data.std()
'''
print("Sum of columns:\n",data.sum())
print("Mean of columns:\n",data.mean())
print("Standard deviation of columns:\n",data.std())
print("Basic Stats: \n",data.describe())
print("Last 10 rows: \n",data.tail(10))
print("Basic stats on second column: \n",data.iloc[:,1].describe())
# Out:
# First 5 rows:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df.type()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b1a68fcb0857> in <module>
# ----> 1 df.type()
#
# NameError: name 'df' is not defined
